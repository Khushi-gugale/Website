# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
mydb=mysql.connector.connect(host="localhost",user="root",passwd="krhusthui!01@17",)

# %%
mycursor=mydb.cursor()
mycursor.execute("CREATE DATABASE mygoogle2")

# %%
# MyISAM and InnoDB are the 2 engins in mysql

# %%
# show create table users(table name); to see query

# %%
mydb=mysql.connector.connect(host="localhost",user="root",passwd="krhusthui!01@17",database="mygoogle2")
mycursor=mydb.cursor()
mycursor.execute("CREATE TABLE searchrankdetail (website VARCHAR(255),count VARCHAR(255),remarks VARCHAR(255))")
